# %%
from sklearn.preprocessing import OneHotEncoder
import pandas as pd
import numpy as np
support = np.arange(0, 208)
import matplotlib.pyplot as plt
test_features = pd.read_excel("C:/Users/sumed/Desktop/MyData/MyTest_T_512.xlsx", header=None)
x_test = test_features.iloc[:, :-1].values.astype('float32')
y_test = np.array(test_features[208])

# %%
# Test sample 150

import math

from gramian_angular_field import GAF 
gaf1 = GAF()

import matplotlib
import matplotlib.pyplot as plt

# GIF
from moviepy.editor import VideoClip
from moviepy.video.io.bindings import mplfig_to_npimage

from tools import tabulate
from tools import cos_sum
from tools import create_time_serie
# from gramian_angular_field import transform

# Jupyter
# %matplotlib inline

# Option to write gif
write_gif = False

# Instanciate figure
fig = plt.figure(figsize=(9, 6))

size = 0.33
alignement = 0.1

# Classic plot
ax_carthesian = fig.add_axes([alignement, 0.4, size, size])
# Polar plot
ax_polar = fig.add_axes([alignement + size, 0.4, size, size], polar=True)
# Patchwork
ax_patchwork = fig.add_axes([alignement + 1.8*size, 0.4, size, size])

# Global iteration
iteration = 0

# PLOTS
global size_time_serie
size_time_serie = float(208)

def make_frame(time):
    # Timesteps
    global iteration

    # Data
#     t, time_serie = create_time_serie(45, 0)
    t = 208
    time_serie = x_test[150]
    
#     gaf, phi, r, scaled_time_serie = gramian_angular_field(time_serie)
    gaf, phi, r, scaled_time_serie = gaf1.transform(time_serie) 

    # Set to 0 unkown data at time stamp iteration
    #t[iteration:] = 0
#     time_serie[iteration:] = 0
#     scaled_time_serie[iteration:] = 0
#     phi[iteration:] = math.acos(0)
    #r[iteration:] = 0
#     gaf[iteration:, iteration:] = 0

    # PLOTS
    font = {
        'family': 'serif',
        'color':  'darkblue',
        'weight': 'normal',
        'size': 16,
        }

    # Clear plot
    ax_carthesian.clear()
    ax_polar.clear()
    ax_patchwork.clear()

    # Original Time series
    ax_carthesian.plot(support, scaled_time_serie)
    ax_carthesian.set_title("Scaled Time Serie", fontdict=font)
    ax_carthesian.set_xticklabels([])

    # Polar encoding
    ax_polar.plot(phi, r)
    ax_polar.set_title("Polar Encoding", fontdict=font)
    ax_polar.set_rticks([0, 1])
    ax_polar.set_rlabel_position(-22.5)
    ax_polar.grid(True)

    # Gramian Angular Field
    ax_patchwork.matshow(gaf)
    ax_patchwork.set_title("Gramian Angular Field", fontdict=font)
    ax_patchwork.set_yticklabels([])
    ax_patchwork.set_xticklabels([])

    iteration = iteration + 1

    return mplfig_to_npimage(fig)


if __name__ == "__main__":

    # GIF: Write and visualise
    animation = VideoClip(make_frame, duration=2)

    if(write_gif):
        animation.write_gif("gramian_angulat_field.gif",fps=20)

    animation.ipython_display(fps=20, loop=True, autoplay=True)
# Out:
# t:   5%|███▌                                                                  | 2/40 [00:00<00:02, 14.67it/s, now=None]
# Moviepy - Building video __temp__.mp4.
# Moviepy - Writing video __temp__.mp4
# Moviepy - Done !
# Moviepy - video ready __temp__.mp4

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(x_test[i], cmap=plt.cm.binary)
    plt.xlabel(a[i])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-ac20345468e3> in <module>()
#       5     plt.yticks([])
#       6     plt.grid(False)
# ----> 7     plt.imshow(x_test[i], cmap=plt.cm.binary)
#       8     plt.xlabel(a[i])
#       9 plt.show()
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, hold, data, **kwargs)
#    3203                         filternorm=filternorm, filterrad=filterrad,
#    3204                         imlim=imlim, resample=resample, url=url, data=data,
# -> 3205                         **kwargs)
#    3206     finally:
#    3207         ax._hold = washold
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1853                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1854                         RuntimeWarning, stacklevel=2)
# -> 1855             return func(ax, *args, **kwargs)
#    1856
#    1857         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, **kwargs)
#    5485                               resample=resample, **kwargs)
#    5486
# -> 5487         im.set_data(X)
#    5488         im.set_alpha(alpha)
#    5489         if im.get_clip_path() is None:
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\image.py in set_data(self, A)
#     651         if not (self._A.ndim == 2
#     652                 or self._A.ndim == 3 and self._A.shape[-1] in [3, 4]):
# --> 653             raise TypeError("Invalid dimensions for image data")
#     654
#     655         if self._A.ndim == 3:
#
# TypeError: Invalid dimensions for image data
